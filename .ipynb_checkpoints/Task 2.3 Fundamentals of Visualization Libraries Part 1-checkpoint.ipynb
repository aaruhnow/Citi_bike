# %% [markdown]
# ## Task 2.3: Fundamentals of Visualization Libraries Part 1
# #### 1. Install Libraries
# #### 2. Read in dataset from previous task
# #### 3. Create a line plot of the temperatures for 2022 plotted as time series using the weather dataframe
# #### 4. Create a column with the count of trips per day and merge it with the weather dataframe
# #### 5. Create a line chart of bike trip counts and temperatures plotted on a dual axis
# #### 6. In a markdown cell, briefly explain your code; how did you use Matplotlib to achieve this? Which paradigm did you use?
# #### 7. Save Plot as file

# %% [markdown]
# ### 1. Install Libraries

# %%
# Installing libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import matplotlib as mpl

# %%
# Checking matplotlib version
import matplotlib
matplotlib.__version__
# Out:
# '3.7.1'

# %% [markdown]
# ### 2. Read in dataset from previous task

# %%
# Importing LaGuardia_data.csv file
df = pd.read_csv('LaGuardia_data.csv')
# Out:
# /var/folders/qg/tbv61t9j3ngdmw6m2qtbk34w0000gn/T/ipykernel_26878/2892705336.py:2: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('LaGuardia_data.csv')

# %%
df
# Out:
#           Unnamed: 0           ride_id  rideable_type  \
# 0                  0  9D0DC440CB40CF8E  electric_bike
# 1                  1  2214991DFBE5C4D7  electric_bike
# 2                  2  20C5D469563B6337   classic_bike
# 3                  3  3E8791885BC189D1   classic_bike
# 4                  4  8DBCBF98885106CB  electric_bike
# ...              ...               ...            ...
# 29838801    29838801  1F223EDAFF420AE3  electric_bike
# 29838802    29838802  CFA5C560ACB73B8E   classic_bike
# 29838803    29838803  11C8C5E0DB947B07   classic_bike
# 29838804    29838804  5B9B083C534A5964   classic_bike
# 29838805    29838805  91C286C462F89A50   classic_bike
#
#                        started_at                 ended_at  \
# 0         2022-08-27 13:56:47.728  2022-08-27 14:02:56.651
# 1         2022-08-20 10:37:02.756  2022-08-20 10:45:56.631
# 2         2022-08-31 18:55:03.051  2022-08-31 19:03:37.344
# 3         2022-08-02 08:05:00.250  2022-08-02 08:16:52.063
# 4         2022-08-25 15:44:48.386  2022-08-25 15:55:39.691
# ...                           ...                      ...
# 29838801  2022-12-01 20:26:45.847  2022-12-01 20:30:46.012
# 29838802  2022-12-26 13:46:34.237  2022-12-26 13:52:43.900
# 29838803  2022-12-01 05:56:14.903  2022-12-01 06:06:10.357
# 29838804  2022-12-02 11:54:15.871  2022-12-02 12:01:00.747
# 29838805  2022-12-18 13:35:22.574  2022-12-18 13:37:27.193
#
#                 start_station_name start_station_id  \
# 0         Flatbush Ave & Ocean Ave          3704.04
# 1           Forsyth St\t& Grand St          5382.07
# 2           Perry St & Bleecker St          5922.07
# 3              FDR Drive & E 35 St          6230.04
# 4                  E 40 St & 5 Ave          6474.11
# ...                            ...              ...
# 29838801         Avenue D & E 3 St          5436.09
# 29838802            43 Ave & 47 St          6209.05
# 29838803         Avenue D & E 3 St          5436.09
# 29838804  Montague St & Clinton St          4677.06
# 29838805  Montague St & Clinton St          4677.06
#
#                            end_station_name end_station_id  start_lat  \
# 0                 3 St & Prospect Park West        3865.05  40.663657
# 1                           E 11 St & 1 Ave        5746.14  40.717798
# 2                      Grand St & Greene St        5500.02  40.735354
# 3         Grand Army Plaza & Central Park S         6839.1  40.744219
# 4                           Ave A & E 14 St        5779.11  40.752052
# ...                                     ...            ...        ...
# 29838801           Stanton St & Chrystie St        5523.02  40.720701
# 29838802                     39 Ave & 45 St        6401.03  40.744806
# 29838803            Bleecker St & Crosby St        5679.08  40.720828
# 29838804                  Sands St & Jay St        4821.03  40.694271
# 29838805        Cadman Plaza E & Tillary St        4677.01  40.694271
#
#           start_lng    end_lat    end_lng member_casual        date  avgTemp  \
# 0        -73.963014  40.668132 -73.973638        casual  2022-08-27    82.04
# 1        -73.993161  40.729538 -73.984267        casual  2022-08-20    82.22
# 2        -74.004831  40.721700 -74.002381        member  2022-08-31    78.08
# 3        -73.971212  40.764397 -73.973715        member  2022-08-02    79.52
# 4        -73.982115  40.730311 -73.980472        member  2022-08-25    82.58
# ...             ...        ...        ...           ...         ...      ...
# 29838801 -73.977939  40.722293 -73.991475        member  2022-12-01    42.26
# 29838802 -73.917290  40.749478 -73.918265        member  2022-12-26    23.54
# 29838803 -73.977932  40.726156 -73.995102        member  2022-12-01    42.26
# 29838804 -73.992327  40.700119 -73.986200        member  2022-12-02    38.12
# 29838805 -73.992327  40.695977 -73.990149        member  2022-12-18    37.58
#
#          _merge
# 0          both
# 1          both
# 2          both
# 3          both
# 4          both
# ...         ...
# 29838801   both
# 29838802   both
# 29838803   both
# 29838804   both
# 29838805   both
#
# [29838806 rows x 17 columns]

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
# Dropping '_merge' column
df.drop(columns = {'_merge'}, inplace = True)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %%
# Convert 'date' to datetime format
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ### 3. Create a line plot of the temperatures for 2022 plotted as time series using the weather dataframe

# %%
df_temp = df.copy()

# %%
df_temp.dtypes
# Out:
# Unnamed: 0                     int64
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %%
# Set the 'date' column to be index
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#             Unnamed: 0           ride_id  rideable_type  \
# date
# 2022-08-27           0  9D0DC440CB40CF8E  electric_bike
# 2022-08-20           1  2214991DFBE5C4D7  electric_bike
# 2022-08-31           2  20C5D469563B6337   classic_bike
# 2022-08-02           3  3E8791885BC189D1   classic_bike
# 2022-08-25           4  8DBCBF98885106CB  electric_bike
#
#                          started_at                 ended_at  \
# date
# 2022-08-27  2022-08-27 13:56:47.728  2022-08-27 14:02:56.651
# 2022-08-20  2022-08-20 10:37:02.756  2022-08-20 10:45:56.631
# 2022-08-31  2022-08-31 18:55:03.051  2022-08-31 19:03:37.344
# 2022-08-02  2022-08-02 08:05:00.250  2022-08-02 08:16:52.063
# 2022-08-25  2022-08-25 15:44:48.386  2022-08-25 15:55:39.691
#
#                   start_station_name start_station_id  \
# date
# 2022-08-27  Flatbush Ave & Ocean Ave          3704.04
# 2022-08-20    Forsyth St\t& Grand St          5382.07
# 2022-08-31    Perry St & Bleecker St          5922.07
# 2022-08-02       FDR Drive & E 35 St          6230.04
# 2022-08-25           E 40 St & 5 Ave          6474.11
#
#                              end_station_name end_station_id  start_lat  \
# date
# 2022-08-27          3 St & Prospect Park West        3865.05  40.663657
# 2022-08-20                    E 11 St & 1 Ave        5746.14  40.717798
# 2022-08-31               Grand St & Greene St        5500.02  40.735354
# 2022-08-02  Grand Army Plaza & Central Park S         6839.1  40.744219
# 2022-08-25                    Ave A & E 14 St        5779.11  40.752052
#
#             start_lng    end_lat    end_lng member_casual  avgTemp
# date
# 2022-08-27 -73.963014  40.668132 -73.973638        casual    82.04
# 2022-08-20 -73.993161  40.729538 -73.984267        casual    82.22
# 2022-08-31 -74.004831  40.721700 -74.002381        member    78.08
# 2022-08-02 -73.971212  40.764397 -73.973715        member    79.52
# 2022-08-25 -73.982115  40.730311 -73.980472        member    82.58

# %%
# Removing unwanted index column
if 'index' in df_temp.columns:
    df_temp.drop(columns=['index'], inplace=True)

# %%
print(df_temp.head())
# Out:
#             Unnamed: 0           ride_id  rideable_type  \
# date
# 2022-08-27           0  9D0DC440CB40CF8E  electric_bike
# 2022-08-20           1  2214991DFBE5C4D7  electric_bike
# 2022-08-31           2  20C5D469563B6337   classic_bike
# 2022-08-02           3  3E8791885BC189D1   classic_bike
# 2022-08-25           4  8DBCBF98885106CB  electric_bike
#
#                          started_at                 ended_at  \
# date
# 2022-08-27  2022-08-27 13:56:47.728  2022-08-27 14:02:56.651
# 2022-08-20  2022-08-20 10:37:02.756  2022-08-20 10:45:56.631
# 2022-08-31  2022-08-31 18:55:03.051  2022-08-31 19:03:37.344
# 2022-08-02  2022-08-02 08:05:00.250  2022-08-02 08:16:52.063
# 2022-08-25  2022-08-25 15:44:48.386  2022-08-25 15:55:39.691
#
#                   start_station_name start_station_id  \
# date
# 2022-08-27  Flatbush Ave & Ocean Ave          3704.04
# 2022-08-20    Forsyth St\t& Grand St          5382.07
# 2022-08-31    Perry St & Bleecker St          5922.07
# 2022-08-02       FDR Drive & E 35 St          6230.04
# 2022-08-25           E 40 St & 5 Ave          6474.11
#
#                              end_station_name end_station_id  start_lat  \
# date
# 2022-08-27          3 St & Prospect Park West        3865.05  40.663657
# 2022-08-20                    E 11 St & 1 Ave        5746.14  40.717798
# 2022-08-31               Grand St & Greene St        5500.02  40.735354
# 2022-08-02  Grand Army Plaza & Central Park S         6839.1  40.744219
# 2022-08-25                    Ave A & E 14 St        5779.11  40.752052
#
#             start_lng    end_lat    end_lng member_casual  avgTemp
# date
# 2022-08-27 -73.963014  40.668132 -73.973638        casual    82.04
# 2022-08-20 -73.993161  40.729538 -73.984267        casual    82.22
# 2022-08-31 -74.004831  40.721700 -74.002381        member    78.08
# 2022-08-02 -73.971212  40.764397 -73.973715        member    79.52
# 2022-08-25 -73.982115  40.730311 -73.980472        member    82.58

# %%
print(df_temp.columns)
# Out:
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp'],
#       dtype='object')

# %%
print(df_temp.index)
# Out:
# DatetimeIndex(['2022-08-27', '2022-08-20', '2022-08-31', '2022-08-02',
#                '2022-08-25', '2022-08-24', '2022-08-15', '2022-08-16',
#                '2022-08-31', '2022-08-28',
#                ...
#                '2022-12-04', '2022-12-10', '2022-12-30', '2022-12-19',
#                '2022-12-05', '2022-12-01', '2022-12-26', '2022-12-01',
#                '2022-12-02', '2022-12-18'],
#               dtype='datetime64[ns]', name='date', length=29838806, freq=None)

# %%
# Due to overlow error msg, updating chunksize to higher value
mpl.rcParams['agg.path.chunksize'] = 10000 

# Filter the DataFrame to include only rows for the specific station
filtered_df = df_temp[df_temp['start_station_name'] == 'Flatbush Ave & Ocean Ave'] 
filtered_df = filtered_df.sort_values(by='date')

# Plot the average temperature for the filtered data
filtered_df['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### 4. Create a column with the count of trips per day and merge it with the weather dataframe

# %%
df_temp.columns
# Out:
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 
df_trip_counts_per_day = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_trip_counts_per_day.head(100)
# Out:
#          date  ride_id
# 0  2022-01-01    20763
# 1  2022-01-02    42458
# 2  2022-01-03    33201
# 3  2022-01-04    36616
# 4  2022-01-05    34609
# ..        ...      ...
# 95 2022-04-06    48279
# 96 2022-04-07    35519
# 97 2022-04-08    87615
# 98 2022-04-09    67572
# 99 2022-04-10    57378
#
# [100 rows x 2 columns]

# %%
# Merge the trip counts with the weather DataFrame
df_trip_counts_per_day.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_trip_counts_per_day, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2022-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2022-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          29838806
# left_only            0
# right_only           0
# Name: count, dtype: int64
# Shape of January 1st is (20763, 18)
# Shape of January 2nd is (42458, 18)
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df_temp.head(1000)
# Out:
#             Unnamed: 0           ride_id  rideable_type  \
# date
# 2022-01-01    27222243  ECDFB9C97FAF0F35   classic_bike
# 2022-01-01    27222411  22F675B5C5A666FD   classic_bike
# 2022-01-01    27222488  38347DF656A7074B   classic_bike
# 2022-01-01    27222685  39DBCC00E8BCCFCF   classic_bike
# 2022-01-01    27222714  FB8B1C38D9B41889  electric_bike
# ...                ...               ...            ...
# 2022-01-01    28268745  AC7AF19AC53F3DEE   classic_bike
# 2022-01-01    28268830  72543A0279889F5B  electric_bike
# 2022-01-01    28268866  DF97688105200BB3  electric_bike
# 2022-01-01    28268896  FAAA00CBCCAB2C53   classic_bike
# 2022-01-01    28268898  636EF1BB86B8894C   classic_bike
#
#                          started_at                 ended_at  \
# date
# 2022-01-01  2022-01-01 13:38:37.927  2022-01-01 13:45:58.200
# 2022-01-01  2022-01-01 00:18:07.680  2022-01-01 01:19:41.047
# 2022-01-01  2021-12-31 22:46:20.965  2022-01-01 01:17:51.394
# 2022-01-01  2022-01-01 22:40:32.125  2022-01-01 22:46:53.380
# 2022-01-01  2022-01-01 14:46:57.116  2022-01-01 14:53:41.673
# ...                             ...                      ...
# 2022-01-01  2021-12-31 23:53:33.397  2022-01-01 00:04:44.031
# 2022-01-01  2022-01-01 00:13:18.145  2022-01-01 01:25:13.965
# 2022-01-01  2022-01-01 19:23:46.844  2022-01-01 19:45:54.988
# 2022-01-01  2022-01-01 00:28:45.050  2022-01-01 00:37:59.538
# 2022-01-01  2022-01-01 10:11:03.613  2022-01-01 10:19:13.597
#
#                    start_station_name start_station_id  \
# date
# 2022-01-01            W 13 St & 7 Ave          6030.04
# 2022-01-01         W 42 St & Dyer Ave          6644.07
# 2022-01-01    University Pl & E 14 St          5905.14
# 2022-01-01            8 Ave & W 27 St          6297.07
# 2022-01-01    University Pl & E 14 St          5905.14
# ...                               ...              ...
# 2022-01-01         Broadway & E 14 St          5905.12
# 2022-01-01         Water St & Main St          4936.14
# 2022-01-01  Greene Ave & Nostrand Ave          4519.02
# 2022-01-01            8 Ave & W 52 St          6816.07
# 2022-01-01            8 Ave & W 52 St          6816.07
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-01-01               Great Jones St        5636.11  40.737815 -73.999947
# 2022-01-01        West St & Chambers St        5329.03  40.758985 -73.993800
# 2022-01-01     W 110 St & Amsterdam Ave        7646.04  40.734814 -73.992085
# 2022-01-01              E 31 St & 3 Ave        6239.08  40.747968 -73.996637
# 2022-01-01              E 31 St & 3 Ave        6239.08  40.734814 -73.992085
# ...                                 ...            ...        ...        ...
# 2022-01-01              6 Ave & W 34 St         6364.1  40.734546 -73.990741
# 2022-01-01              6 Ave & W 34 St         6364.1  40.703212 -73.990409
# 2022-01-01        Canal St & Rutgers St        5303.08  40.688334 -73.950916
# 2022-01-01  Central Park West & W 72 St        7141.07  40.763707 -73.985162
# 2022-01-01  Central Park West & W 72 St        7141.07  40.763707 -73.985162
#
#               end_lat    end_lng member_casual  avgTemp  bike_rides_daily  \
# date
# 2022-01-01  40.727434 -73.993790        casual    52.88             20763
# 2022-01-01  40.717548 -74.013221        casual    52.88             20763
# 2022-01-01  40.802692 -73.962950        casual    52.88             20763
# 2022-01-01  40.743943 -73.979661        member    52.88             20763
# 2022-01-01  40.743943 -73.979661        member    52.88             20763
# ...               ...        ...           ...      ...               ...
# 2022-01-01  40.749640 -73.988050        member    52.88             20763
# 2022-01-01  40.749640 -73.988050        casual    52.88             20763
# 2022-01-01  40.714275 -73.989900        member    52.88             20763
# 2022-01-01  40.775794 -73.976206        casual    52.88             20763
# 2022-01-01  40.775794 -73.976206        casual    52.88             20763
#
#            _merge
# date
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# ...           ...
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
# 2022-01-01   both
#
# [1000 rows x 17 columns]

# %% [markdown]
# ### 5. Create a line chart of bike trip counts and temperatures plotted on a dual axis

# %%
# Create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize=(10, 5))

# Create a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")

# Create the dual axis
ax2 = ax.twinx()

# Create a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "blue")
plt.show()

# %%
# Create figure and axis objects with subplots() and details
fig,ax = plt.subplots(figsize=(10, 5))

# Create a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "navy")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Create the dual axis 
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "red")
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %% [markdown]
# ### 6. In a markdown cell, briefly explain your code; how did you use Matplotlib to achieve this? Which paradigm did you use?

# %% [markdown]
# #### I used Matplotlib's Object-Oriented Approach to create two figures that visualize the relationship between bike rides and average temperatures. The first plot visualizes both bike rides and average temperatures on a dual y-axis. The second plot adds labels and a title to better describe the data, along with customized colors—navy for bike rides and red for temperatures—to distinguish between the two datasets. This approach allowed me to create dual-axis plots, manage each figure element (such as labels, colors, and titles) in an organized manner, and clearly differentiate the data by using separate axis objects.
